# %% [markdown]
# # Origins
#
# Origins is introspection, indexer, and semantic analyzer of data elements. It connects to a source of data and indexes the data elements, gathering as much as metadata as it can.

# %%
# Ensure origins is on the path
import os
import sys
sys.path.insert(0, os.path.abspath('..'))

import origins

# %% [markdown]
# ## Connecting to a data source
#
# Data sources are connected to by using Origin's _backends_. To see all available backends and their import locations:

# %%
origins.BACKENDS
# Out:
# {u'sqlite': u'origins.backends.sqlite'}

# %% [markdown]
# If you're curious if your environment supports a particular backend (for dependencies) you can perform the check prior to connecting to it by using the `check_backend` function. If `None` is returned everything is good, otherwise the reason the backend is not supported will be returned.

# %%
origins.check_backend('sqlite') # good
origins.check_backend('foobar') # unknown
# Out:
# u'unknown backend: foobar'

# %% [markdown]
# Connect to a backend by using the `connect` function. The backend name followed by keyword arguments specific to that backend must be supplied (arguments are listed in the documentation). We will connect to a SQLite build of the [Chinook database](http://chinookdatabase.codeplex.com/).

# %%
db = origins.connect('sqlite', path='../tests/data/chinook.sqlite')

# %% [markdown]
# `connect` returns the _origin node_ of the data source. All nodes have attributes which may vary across backends since each have their own unique characteristcs. However every node is guaranteed to have a `id` which uniquely identifies itself across all the nodes (more on this next).

# %%
db
# Out:
# {u'backend': 'sqlite',
#  u'id': u'chinook.sqlite',
#  'path': '../tests/data/chinook.sqlite',
#  u'size': 1067008,
#  u'version': 32}

# %% [markdown]
# To reiterate, Origins makes it trivial to access all the data elements in a particular data source. This can be done by accessing the `elements` property:

# %%
db.elements
# Out:
# [{u'column_name': u'State',
#  u'count': 30,
#  u'default': None,
#  u'id': u'chinook.sqlite:Customer:State',
#  u'nullable': True,
#  u'position': 6,
#  u'primary_key': 0,
#  u'source': u'Customer',
#  u'table_name': u'Customer',
#  u'type': u'NVARCHAR(40)',
#  u'unique_count': 25},
#  {u'column_name': u'Email',
#  u'count': 8,
#  u'default': None,
#  u'id': u'chinook.sqlite:Employee:Email',
#  u'nullable': True,
#  u'position': 14,
#  u'primary_key': 0,
#  u'source': u'Employee',
#  u'table_name': u'Employee',
#  u'type': u'NVARCHAR(60)',
#  u'unique_count': 8},
#  {u'column_name': u'LastName',
#  u'count': 8,
#  u'default': None,
#  u'id': u'chinook.sqlite:Employee:LastName',
#  u'nullable': False,
#  u'position': 1,
#  u'primary_key': 0,
#  u'source': u'Employee',
#  u'table_name': u'Employee',
#  u'type': u'NVARCHAR(20)',
#  u'unique_count': 8},
#  {u'column_name': u'Country',
#  u'count': 59,
#  u'default': None,
#  u'id': u'chinook.sqlite:Customer:Country',
#  u'nullable': True,
#  u'position': 7,
#  u'primary_key': 0,
#  u'source': u'Customer',
#  u'table_name': u'Customer',
#  u'type': u'NVARCHAR(40)',
#  u'unique_count': 24},
#  {u'column_name': u'LastName',
#  u'count': 59,
#  u'default': None,
#  u'id': u'chinook.sqlite:Customer:LastName',
#  u'nullable': False,
#  u'position': 2,
#  u'primary_key': 0,
#  u'source': u'Customer',
#  u'table_name': u'Customer',
#  u'type': u'NVARCHAR(20)',
#  u'unique_count': 59},
#  {u'column_name': u'TrackId',
#  u'count': 8715,
#  u'default': None,
#  u'id': u'chinook.sqlite:PlaylistTrack:TrackId',
#  u'nullable': False,
#  u'position': 1,
#  u'primary_key': 1,
#  u'source': u'PlaylistTrack',
#  u'table_name': u'PlaylistTrack',
#  u'type': u'INTEGER',
#  u'unique_count': 3503},
#  {u'column_name': u'BillingPostalCode',
#  u'count': 384,
#  u'default': None,
#  u'id': u'chinook.sqlite:Invoice:BillingPostalCode',
#  u'nullable': True,
#  u'position': 7,
#  u'primary_key': 0,
#  u'source': u'Invoice',
#  u'table_name': u'Invoice',
#  u'type': u'NVARCHAR(10)',
#  u'unique_count': 55},
#  {u'column_name': u'Title',
#  u'count': 347,
#  u'default': None,
#  u'id': u'chinook.sqlite:Album:Title',
#  u'nullable': False,
#  u'position': 1,
#  u'primary_key': 0,
#  u'source': u'Album',
#  u'table_name': u'Album',
#  u'type': u'NVARCHAR(160)',
#  u'unique_count': 347},
#  {u'column_name': u'Name',
#  u'count': 275,
#  u'default': None,
#  u'id': u'chinook.sqlite:Artist:Name',
#  u'nullable': True,
#  u'position': 1,
#  u'primary_key': 0,
#  u'source': u'Artist',
#  u'table_name': u'Artist',
#  u'type': u'NVARCHAR(120)',
#  u'unique_count': 275},
#  {u'column_name': u'SupportRepId',
#  u'count': 59,
#  u'default': None,
#  u'id': u'chinook.sqlite:Customer:SupportRepId',
#  u'nullable': True,
#  u'position': 12,
#  u'primary_key': 0,
#  u'source': u'Customer',
#  u'table_name': u'Customer',
#  u'type': u'INTEGER',
#  u'unique_count': 3},
#  {u'column_name': u'InvoiceLineId',
#  u'count': 2240,
#  u'default': None,
#  u'id': u'chinook.sqlite:InvoiceLine:InvoiceLineId',
#  u'nullable': False,
#  u'position': 0,
#  u'primary_key': 1,
#  u'source': u'InvoiceLine',
#  u'table_name': u'InvoiceLine',
#  u'type': u'INTEGER',
#  u'unique_count': 2240},
#  {u'column_name': u'CustomerId',
#  u'count': 412,
#  u'default': None,
#  u'id': u'chinook.sqlite:Invoice:CustomerId',
#  u'nullable': False,
#  u'position': 1,
#  u'primary_key': 0,
#  u'source': u'Invoice',
#  u'table_name': u'Invoice',
#  u'type': u'INTEGER',
#  u'unique_count': 59},
#  {u'column_name': u'Bytes',
#  u'count': 3503,
#  u'default': None,
#  u'id': u'chinook.sqlite:Track:Bytes',
#  u'nullable': True,
#  u'position': 7,
#  u'primary_key': 0,
#  u'source': u'Track',
#  u'table_name': u'Track',
#  u'type': u'INTEGER',
#  u'unique_count': 3501},
#  {u'column_name': u'Name',
#  u'count': 18,
#  u'default': None,
#  u'id': u'chinook.sqlite:Playlist:Name',
#  u'nullable': True,
#  u'position': 1,
#  u'primary_key': 0,
#  u'source': u'Playlist',
#  u'table_name': u'Playlist',
#  u'type': u'NVARCHAR(120)',
#  u'unique_count': 14},
#  {u'column_name': u'InvoiceId',
#  u'count': 2240,
#  u'default': None,
#  u'id': u'chinook.sqlite:InvoiceLine:InvoiceId',
#  u'nullable': False,
#  u'position': 1,
#  u'primary_key': 0,
#  u'source': u'InvoiceLine',
#  u'table_name': u'InvoiceLine',
#  u'type': u'INTEGER',
#  u'unique_count': 412},
#  {u'column_name': u'Milliseconds',
#  u'count': 3503,
#  u'default': None,
#  u'id': u'chinook.sqlite:Track:Milliseconds',
#  u'nullable': False,
#  u'position': 6,
#  u'primary_key': 0,
#  u'source': u'Track',
#  u'table_name': u'Track',
#  u'type': u'INTEGER',
#  u'unique_count': 3080},
#  {u'column_name': u'BillingAddress',
#  u'count': 412,
#  u'default': None,
#  u'id': u'chinook.sqlite:Invoice:BillingAddress',
#  u'nullable': True,
#  u'position': 3,
#  u'primary_key': 0,
#  u'source': u'Invoice',
#  u'table_name': u'Invoice',
#  u'type': u'NVARCHAR(70)',
#  u'unique_count': 59},
#  {u'column_name': u'HireDate',
#  u'count': 8,
#  u'default': None,
#  u'id': u'chinook.sqlite:Employee:HireDate',
#  u'nullable': True,
#  u'position': 6,
#  u'primary_key': 0,
#  u'source': u'Employee',
#  u'table_name': u'Employee',
#  u'type': u'DATETIME',
#  u'unique_count': 7},
#  {u'column_name': u'Email',
#  u'count': 59,
#  u'default': None,
#  u'id': u'chinook.sqlite:Customer:Email',
#  u'nullable': False,
#  u'position': 11,
#  u'primary_key': 0,
#  u'source': u'Customer',
#  u'table_name': u'Customer',
#  u'type': u'NVARCHAR(60)',
#  u'unique_count': 59},
#  {u'column_name': u'MediaTypeId',
#  u'count': 3503,
#  u'default': None,
#  u'id': u'chinook.sqlite:Track:MediaTypeId',
#  u'nullable': False,
#  u'position': 3,
#  u'primary_key': 0,
#  u'source': u'Track',
#  u'table_name': u'Track',
#  u'type': u'INTEGER',
#  u'unique_count': 5},
#  {u'column_name': u'BillingCountry',
#  u'count': 412,
#  u'default': None,
#  u'id': u'chinook.sqlite:Invoice:BillingCountry',
#  u'nullable': True,
#  u'position': 6,
#  u'primary_key': 0,
#  u'source': u'Invoice',
#  u'table_name': u'Invoice',
#  u'type': u'NVARCHAR(40)',
#  u'unique_count': 24},
#  {u'column_name': u'CustomerId',
#  u'count': 59,
#  u'default': None,
#  u'id': u'chinook.sqlite:Customer:CustomerId',
#  u'nullable': False,
#  u'position': 0,
#  u'primary_key': 1,
#  u'source': u'Customer',
#  u'table_name': u'Customer',
#  u'type': u'INTEGER',
#  u'unique_count': 59},
#  {u'column_name': u'MediaTypeId',
#  u'count': 5,
#  u'default': None,
#  u'id': u'chinook.sqlite:MediaType:MediaTypeId',
#  u'nullable': False,
#  u'position': 0,
#  u'primary_key': 1,
#  u'source': u'MediaType',
#  u'table_name': u'MediaType',
#  u'type': u'INTEGER',
#  u'unique_count': 5},
#  {u'column_name': u'BillingCity',
#  u'count': 412,
#  u'default': None,
#  u'id': u'chinook.sqlite:Invoice:BillingCity',
#  u'nullable': True,
#  u'position': 4,
#  u'primary_key': 0,
#  u'source': u'Invoice',
#  u'table_name': u'Invoice',
#  u'type': u'NVARCHAR(40)',
#  u'unique_count': 53},
#  {u'column_name': u'Phone',
#  u'count': 8,
#  u'default': None,
#  u'id': u'chinook.sqlite:Employee:Phone',
#  u'nullable': True,
#  u'position': 12,
#  u'primary_key': 0,
#  u'source': u'Employee',
#  u'table_name': u'Employee',
#  u'type': u'NVARCHAR(24)',
#  u'unique_count': 7},
#  {u'column_name': u'PostalCode',
#  u'count': 55,
#  u'default': None,
#  u'id': u'chinook.sqlite:Customer:PostalCode',
#  u'nullable': True,
#  u'position': 8,
#  u'primary_key': 0,
#  u'source': u'Customer',
#  u'table_name': u'Customer',
#  u'type': u'NVARCHAR(10)',
#  u'unique_count': 55},
#  {u'column_name': u'Phone',
#  u'count': 58,
#  u'default': None,
#  u'id': u'chinook.sqlite:Customer:Phone',
#  u'nullable': True,
#  u'position': 9,
#  u'primary_key': 0,
#  u'source': u'Customer',
#  u'table_name': u'Customer',
#  u'type': u'NVARCHAR(24)',
#  u'unique_count': 58},
#  {u'column_name': u'UnitPrice',
#  u'count': 3503,
#  u'default': None,
#  u'id': u'chinook.sqlite:Track:UnitPrice',
#  u'nullable': False,
#  u'position': 8,
#  u'primary_key': 0,
#  u'source': u'Track',
#  u'table_name': u'Track',
#  u'type': u'NUMERIC(10,2)',
#  u'unique_count': 2},
#  {u'column_name': u'PlaylistId',
#  u'count': 18,
#  u'default': None,
#  u'id': u'chinook.sqlite:Playlist:PlaylistId',
#  u'nullable': False,
#  u'position': 0,
#  u'primary_key': 1,
#  u'source': u'Playlist',
#  u'table_name': u'Playlist',
#  u'type': u'INTEGER',
#  u'unique_count': 18},
#  {u'column_name': u'Country',
#  u'count': 8,
#  u'default': None,
#  u'id': u'chinook.sqlite:Employee:Country',
#  u'nullable': True,
#  u'position': 10,
#  u'primary_key': 0,
#  u'source': u'Employee',
#  u'table_name': u'Employee',
#  u'type': u'NVARCHAR(40)',
#  u'unique_count': 1},
#  {u'column_name': u'AlbumId',
#  u'count': 3503,
#  u'default': None,
#  u'id': u'chinook.sqlite:Track:AlbumId',
#  u'nullable': True,
#  u'position': 2,
#  u'primary_key': 0,
#  u'source': u'Track',
#  u'table_name': u'Track',
#  u'type': u'INTEGER',
#  u'unique_count': 347},
#  {u'column_name': u'Composer',
#  u'count': 2525,
#  u'default': None,
#  u'id': u'chinook.sqlite:Track:Composer',
#  u'nullable': True,
#  u'position': 5,
#  u'primary_key': 0,
#  u'source': u'Track',
#  u'table_name': u'Track',
#  u'type': u'NVARCHAR(220)',
#  u'unique_count': 852},
#  {u'column_name': u'Address',
#  u'count': 8,
#  u'default': None,
#  u'id': u'chinook.sqlite:Employee:Address',
#  u'nullable': True,
#  u'position': 7,
#  u'primary_key': 0,
#  u'source': u'Employee',
#  u'table_name': u'Employee',
#  u'type': u'NVARCHAR(70)',
#  u'unique_count': 8},
#  {u'column_name': u'GenreId',
#  u'count': 25,
#  u'default': None,
#  u'id': u'chinook.sqlite:Genre:GenreId',
#  u'nullable': False,
#  u'position': 0,
#  u'primary_key': 1,
#  u'source': u'Genre',
#  u'table_name': u'Genre',
#  u'type': u'INTEGER',
#  u'unique_count': 25},
#  {u'column_name': u'Address',
#  u'count': 59,
#  u'default': None,
#  u'id': u'chinook.sqlite:Customer:Address',
#  u'nullable': True,
#  u'position': 4,
#  u'primary_key': 0,
#  u'source': u'Customer',
#  u'table_name': u'Customer',
#  u'type': u'NVARCHAR(70)',
#  u'unique_count': 59},
#  {u'column_name': u'Total',
#  u'count': 412,
#  u'default': None,
#  u'id': u'chinook.sqlite:Invoice:Total',
#  u'nullable': False,
#  u'position': 8,
#  u'primary_key': 0,
#  u'source': u'Invoice',
#  u'table_name': u'Invoice',
#  u'type': u'NUMERIC(10,2)',
#  u'unique_count': 23},
#  {u'column_name': u'ReportsTo',
#  u'count': 7,
#  u'default': None,
#  u'id': u'chinook.sqlite:Employee:ReportsTo',
#  u'nullable': True,
#  u'position': 4,
#  u'primary_key': 0,
#  u'source': u'Employee',
#  u'table_name': u'Employee',
#  u'type': u'INTEGER',
#  u'unique_count': 3},
#  {u'column_name': u'Fax',
#  u'count': 12,
#  u'default': None,
#  u'id': u'chinook.sqlite:Customer:Fax',
#  u'nullable': True,
#  u'position': 10,
#  u'primary_key': 0,
#  u'source': u'Customer',
#  u'table_name': u'Customer',
#  u'type': u'NVARCHAR(24)',
#  u'unique_count': 12},
#  {u'column_name': u'ArtistId',
#  u'count': 275,
#  u'default': None,
#  u'id': u'chinook.sqlite:Artist:ArtistId',
#  u'nullable': False,
#  u'position': 0,
#  u'primary_key': 1,
#  u'source': u'Artist',
#  u'table_name': u'Artist',
#  u'type': u'INTEGER',
#  u'unique_count': 275},
#  {u'column_name': u'State',
#  u'count': 8,
#  u'default': None,
#  u'id': u'chinook.sqlite:Employee:State',
#  u'nullable': True,
#  u'position': 9,
#  u'primary_key': 0,
#  u'source': u'Employee',
#  u'table_name': u'Employee',
#  u'type': u'NVARCHAR(40)',
#  u'unique_count': 1},
#  {u'column_name': u'FirstName',
#  u'count': 8,
#  u'default': None,
#  u'id': u'chinook.sqlite:Employee:FirstName',
#  u'nullable': False,
#  u'position': 2,
#  u'primary_key': 0,
#  u'source': u'Employee',
#  u'table_name': u'Employee',
#  u'type': u'NVARCHAR(20)',
#  u'unique_count': 8},
#  {u'column_name': u'InvoiceDate',
#  u'count': 412,
#  u'default': None,
#  u'id': u'chinook.sqlite:Invoice:InvoiceDate',
#  u'nullable': False,
#  u'position': 2,
#  u'primary_key': 0,
#  u'source': u'Invoice',
#  u'table_name': u'Invoice',
#  u'type': u'DATETIME',
#  u'unique_count': 354},
#  {u'column_name': u'EmployeeId',
#  u'count': 8,
#  u'default': None,
#  u'id': u'chinook.sqlite:Employee:EmployeeId',
#  u'nullable': False,
#  u'position': 0,
#  u'primary_key': 1,
#  u'source': u'Employee',
#  u'table_name': u'Employee',
#  u'type': u'INTEGER',
#  u'unique_count': 8},
#  {u'column_name': u'AlbumId',
#  u'count': 347,
#  u'default': None,
#  u'id': u'chinook.sqlite:Album:AlbumId',
#  u'nullable': False,
#  u'position': 0,
#  u'primary_key': 1,
#  u'source': u'Album',
#  u'table_name': u'Album',
#  u'type': u'INTEGER',
#  u'unique_count': 347},
#  {u'column_name': u'UnitPrice',
#  u'count': 2240,
#  u'default': None,
#  u'id': u'chinook.sqlite:InvoiceLine:UnitPrice',
#  u'nullable': False,
#  u'position': 3,
#  u'primary_key': 0,
#  u'source': u'InvoiceLine',
#  u'table_name': u'InvoiceLine',
#  u'type': u'NUMERIC(10,2)',
#  u'unique_count': 2},
#  {u'column_name': u'Name',
#  u'count': 25,
#  u'default': None,
#  u'id': u'chinook.sqlite:Genre:Name',
#  u'nullable': True,
#  u'position': 1,
#  u'primary_key': 0,
#  u'source': u'Genre',
#  u'table_name': u'Genre',
#  u'type': u'NVARCHAR(120)',
#  u'unique_count': 25},
#  {u'column_name': u'PostalCode',
#  u'count': 8,
#  u'default': None,
#  u'id': u'chinook.sqlite:Employee:PostalCode',
#  u'nullable': True,
#  u'position': 11,
#  u'primary_key': 0,
#  u'source': u'Employee',
#  u'table_name': u'Employee',
#  u'type': u'NVARCHAR(10)',
#  u'unique_count': 8},
#  {u'column_name': u'BillingState',
#  u'count': 210,
#  u'default': None,
#  u'id': u'chinook.sqlite:Invoice:BillingState',
#  u'nullable': True,
#  u'position': 5,
#  u'primary_key': 0,
#  u'source': u'Invoice',
#  u'table_name': u'Invoice',
#  u'type': u'NVARCHAR(40)',
#  u'unique_count': 25},
#  {u'column_name': u'City',
#  u'count': 8,
#  u'default': None,
#  u'id': u'chinook.sqlite:Employee:City',
#  u'nullable': True,
#  u'position': 8,
#  u'primary_key': 0,
#  u'source': u'Employee',
#  u'table_name': u'Employee',
#  u'type': u'NVARCHAR(40)',
#  u'unique_count': 3},
#  {u'column_name': u'Title',
#  u'count': 8,
#  u'default': None,
#  u'id': u'chinook.sqlite:Employee:Title',
#  u'nullable': True,
#  u'position': 3,
#  u'primary_key': 0,
#  u'source': u'Employee',
#  u'table_name': u'Employee',
#  u'type': u'NVARCHAR(30)',
#  u'unique_count': 5},
#  {u'column_name': u'BirthDate',
#  u'count': 8,
#  u'default': None,
#  u'id': u'chinook.sqlite:Employee:BirthDate',
#  u'nullable': True,
#  u'position': 5,
#  u'primary_key': 0,
#  u'source': u'Employee',
#  u'table_name': u'Employee',
#  u'type': u'DATETIME',
#  u'unique_count': 8},
#  {u'column_name': u'TrackId',
#  u'count': 3503,
#  u'default': None,
#  u'id': u'chinook.sqlite:Track:TrackId',
#  u'nullable': False,
#  u'position': 0,
#  u'primary_key': 1,
#  u'source': u'Track',
#  u'table_name': u'Track',
#  u'type': u'INTEGER',
#  u'unique_count': 3503},
#  {u'column_name': u'Company',
#  u'count': 10,
#  u'default': None,
#  u'id': u'chinook.sqlite:Customer:Company',
#  u'nullable': True,
#  u'position': 3,
#  u'primary_key': 0,
#  u'source': u'Customer',
#  u'table_name': u'Customer',
#  u'type': u'NVARCHAR(80)',
#  u'unique_count': 10},
#  {u'column_name': u'City',
#  u'count': 59,
#  u'default': None,
#  u'id': u'chinook.sqlite:Customer:City',
#  u'nullable': True,
#  u'position': 5,
#  u'primary_key': 0,
#  u'source': u'Customer',
#  u'table_name': u'Customer',
#  u'type': u'NVARCHAR(40)',
#  u'unique_count': 53},
#  {u'column_name': u'Name',
#  u'count': 5,
#  u'default': None,
#  u'id': u'chinook.sqlite:MediaType:Name',
#  u'nullable': True,
#  u'position': 1,
#  u'primary_key': 0,
#  u'source': u'MediaType',
#  u'table_name': u'MediaType',
#  u'type': u'NVARCHAR(120)',
#  u'unique_count': 5},
#  {u'column_name': u'FirstName',
#  u'count': 59,
#  u'default': None,
#  u'id': u'chinook.sqlite:Customer:FirstName',
#  u'nullable': False,
#  u'position': 1,
#  u'primary_key': 0,
#  u'source': u'Customer',
#  u'table_name': u'Customer',
#  u'type': u'NVARCHAR(40)',
#  u'unique_count': 57},
#  {u'column_name': u'Fax',
#  u'count': 8,
#  u'default': None,
#  u'id': u'chinook.sqlite:Employee:Fax',
#  u'nullable': True,
#  u'position': 13,
#  u'primary_key': 0,
#  u'source': u'Employee',
#  u'table_name': u'Employee',
#  u'type': u'NVARCHAR(24)',
#  u'unique_count': 8},
#  {u'column_name': u'PlaylistId',
#  u'count': 8715,
#  u'default': None,
#  u'id': u'chinook.sqlite:PlaylistTrack:PlaylistId',
#  u'nullable': False,
#  u'position': 0,
#  u'primary_key': 1,
#  u'source': u'PlaylistTrack',
#  u'table_name': u'PlaylistTrack',
#  u'type': u'INTEGER',
#  u'unique_count': 14},
#  {u'column_name': u'Quantity',
#  u'count': 2240,
#  u'default': None,
#  u'id': u'chinook.sqlite:InvoiceLine:Quantity',
#  u'nullable': False,
#  u'position': 4,
#  u'primary_key': 0,
#  u'source': u'InvoiceLine',
#  u'table_name': u'InvoiceLine',
#  u'type': u'INTEGER',
#  u'unique_count': 1},
#  {u'column_name': u'ArtistId',
#  u'count': 347,
#  u'default': None,
#  u'id': u'chinook.sqlite:Album:ArtistId',
#  u'nullable': False,
#  u'position': 2,
#  u'primary_key': 0,
#  u'source': u'Album',
#  u'table_name': u'Album',
#  u'type': u'INTEGER',
#  u'unique_count': 204},
#  {u'column_name': u'Name',
#  u'count': 3503,
#  u'default': None,
#  u'id': u'chinook.sqlite:Track:Name',
#  u'nullable': False,
#  u'position': 1,
#  u'primary_key': 0,
#  u'source': u'Track',
#  u'table_name': u'Track',
#  u'type': u'NVARCHAR(200)',
#  u'unique_count': 3257},
#  {u'column_name': u'GenreId',
#  u'count': 3503,
#  u'default': None,
#  u'id': u'chinook.sqlite:Track:GenreId',
#  u'nullable': True,
#  u'position': 4,
#  u'primary_key': 0,
#  u'source': u'Track',
#  u'table_name': u'Track',
#  u'type': u'INTEGER',
#  u'unique_count': 25},
#  {u'column_name': u'TrackId',
#  u'count': 2240,
#  u'default': None,
#  u'id': u'chinook.sqlite:InvoiceLine:TrackId',
#  u'nullable': False,
#  u'position': 2,
#  u'primary_key': 0,
#  u'source': u'InvoiceLine',
#  u'table_name': u'InvoiceLine',
#  u'type': u'INTEGER',
#  u'unique_count': 1984},
#  {u'column_name': u'InvoiceId',
#  u'count': 412,
#  u'default': None,
#  u'id': u'chinook.sqlite:Invoice:InvoiceId',
#  u'nullable': False,
#  u'position': 0,
#  u'primary_key': 1,
#  u'source': u'Invoice',
#  u'table_name': u'Invoice',
#  u'type': u'INTEGER',
#  u'unique_count': 412}]

# %% [markdown]
# For a relational database, an element maps to a column on a table. This is obvious with attributes such as `table_name` and `column_name`. Although awesome, this can be a tad overwhelming to look at when wanting to gradually look through the elements.
#
# Since the elements actually exist on tables _within_ the database, the tables are a natural hierarchy for accessing a subset of the elements. As you might expect, you can access the tables via `db.tables`:

# %%
db.tables
# Out:
# [{u'count': 2240,
#  u'id': u'chinook.sqlite:InvoiceLine',
#  u'source': u'chinook.sqlite',
#  u'table_name': u'InvoiceLine'},
#  {u'count': 347,
#  u'id': u'chinook.sqlite:Album',
#  u'source': u'chinook.sqlite',
#  u'table_name': u'Album'},
#  {u'count': 25,
#  u'id': u'chinook.sqlite:Genre',
#  u'source': u'chinook.sqlite',
#  u'table_name': u'Genre'},
#  {u'count': 5,
#  u'id': u'chinook.sqlite:MediaType',
#  u'source': u'chinook.sqlite',
#  u'table_name': u'MediaType'},
#  {u'count': 8715,
#  u'id': u'chinook.sqlite:PlaylistTrack',
#  u'source': u'chinook.sqlite',
#  u'table_name': u'PlaylistTrack'},
#  {u'count': 8,
#  u'id': u'chinook.sqlite:Employee',
#  u'source': u'chinook.sqlite',
#  u'table_name': u'Employee'},
#  {u'count': 18,
#  u'id': u'chinook.sqlite:Playlist',
#  u'source': u'chinook.sqlite',
#  u'table_name': u'Playlist'},
#  {u'count': 3503,
#  u'id': u'chinook.sqlite:Track',
#  u'source': u'chinook.sqlite',
#  u'table_name': u'Track'},
#  {u'count': 412,
#  u'id': u'chinook.sqlite:Invoice',
#  u'source': u'chinook.sqlite',
#  u'table_name': u'Invoice'},
#  {u'count': 275,
#  u'id': u'chinook.sqlite:Artist',
#  u'source': u'chinook.sqlite',
#  u'table_name': u'Artist'},
#  {u'count': 59,
#  u'id': u'chinook.sqlite:Customer',
#  u'source': u'chinook.sqlite',
#  u'table_name': u'Customer'}]

# %% [markdown]
# This lists all the tables in the database and their attributes.
#
# For cross-compatibility between backends, all nodes support the same interface for accessing the both `branches` and `elements`. The backend-specific terms are merely for API convenience when working with the backends programatically.

# %%
db.tables == db.branches
# Out:
# True

# %% [markdown]
# To access a particular table, the `tables` (or `branches`) property can be accessed:

# %%
db.tables['Album']
# Out:
# {u'count': 347,
#  u'id': u'chinook.sqlite:Album',
#  u'source': u'chinook.sqlite',
#  u'table_name': u'Album'}

# %% [markdown]
# Following the same convenience with `db.tables`, the elements can be accessed on the table using the `columns` property.

# %%
db.tables['Album'].columns
# Out:
# [{u'column_name': u'ArtistId',
#  u'count': 347,
#  u'default': None,
#  u'id': u'chinook.sqlite:Album:ArtistId',
#  u'nullable': False,
#  u'position': 2,
#  u'primary_key': 0,
#  u'source': u'Album',
#  u'table_name': u'Album',
#  u'type': u'INTEGER',
#  u'unique_count': 204},
#  {u'column_name': u'Title',
#  u'count': 347,
#  u'default': None,
#  u'id': u'chinook.sqlite:Album:Title',
#  u'nullable': False,
#  u'position': 1,
#  u'primary_key': 0,
#  u'source': u'Album',
#  u'table_name': u'Album',
#  u'type': u'NVARCHAR(160)',
#  u'unique_count': 347},
#  {u'column_name': u'AlbumId',
#  u'count': 347,
#  u'default': None,
#  u'id': u'chinook.sqlite:Album:AlbumId',
#  u'nullable': False,
#  u'position': 0,
#  u'primary_key': 1,
#  u'source': u'Album',
#  u'table_name': u'Album',
#  u'type': u'INTEGER',
#  u'unique_count': 347}]
