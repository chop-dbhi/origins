# %%
# Ensure origins is on the path
import os
import sys
sys.path.insert(0, os.path.abspath('..'))

import origins

# %%
vcf = origins.connect('vcf', path='../tests/data/sample.vcf')

# %%
vcf
# Out:
# File('sample.vcf')

# %%
vcf.props
# Out:
# {'fileformat': 'VCFv4.1',
#  u'name': 'sample.vcf',
#  u'path': '/Users/ruthb/Code/cbmi/origins/tests/data/sample.vcf',
#  'reference': 'GRCh37'}

# %%
vcf.fields
# Out:
# (Field('CHROM'),
#  Field('POS'),
#  Field('ID'),
#  Field('REF'),
#  Field('ALT'),
#  Field('QUAL'),
#  Field('FILTER'),
#  Field('LDAF'),
#  Field('AVGPOST'),
#  Field('RSQ'),
#  Field('ERATE'),
#  Field('THETA'),
#  Field('CIEND'),
#  Field('CIPOS'),
#  Field('END'),
#  Field('HOMLEN'),
#  Field('HOMSEQ'),
#  Field('SVLEN'),
#  Field('SVTYPE'),
#  Field('AC'),
#  Field('AN'),
#  Field('AA'),
#  Field('AF'),
#  Field('AMR_AF'),
#  Field('ASN_AF'),
#  Field('AFR_AF'),
#  Field('EUR_AF'),
#  Field('VT'),
#  Field('SNPSOURCE'),
#  Field('GT'),
#  Field('DS'),
#  Field('GL'))

# %%
vcf.fields['GT']
# Out:
# Field('GT')

# %%
vcf.fields['GT'].props
# Out:
# {u'name': 'GT', u'num_values': 1, u'type': 'String'}
